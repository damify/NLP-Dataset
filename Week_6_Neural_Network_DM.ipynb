# %% [markdown]
# <a href="https://colab.research.google.com/github/damify/NLP-Dataset/blob/main/Week_6_Neural_Network_DM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
cardio_data = pd.read_csv('Cardiotocographic.csv')

# %%
cardio_data=pd.read_csv('Cardiotocographic.csv')
cardio_data.head()
# Out:
#    BPM       APC  FMPS      UCPS      DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 0  120  0.000000   0.0  0.000000  0.000000   0.0   0.0    73   0.5    43
# 1  132  0.006380   0.0  0.006380  0.003190   0.0   0.0    17   2.1     0
# 2  133  0.003322   0.0  0.008306  0.003322   0.0   0.0    16   2.1     0
# 3  134  0.002561   0.0  0.007682  0.002561   0.0   0.0    16   2.4     0
# 4  132  0.006515   0.0  0.008143  0.000000   0.0   0.0    16   2.4     0
#
#    MLTV  Width  Min  Max  NSP
# 0   2.4     64   62  126    2
# 1  10.4    130   68  198    1
# 2  13.4    130   68  198    1
# 3  23.0    117   53  170    1
# 4  19.9    117   53  170    1

# %%
cardio_data.tail()
# Out:
#       BPM       APC      FMPS      UCPS  DLPS  SDPS  PDPS  ASTV  MSTV  ALTV  \
# 2121  140  0.000000  0.000000  0.007426   0.0   0.0   0.0    79   0.2    25
# 2122  140  0.000775  0.000000  0.006971   0.0   0.0   0.0    78   0.4    22
# 2123  140  0.000980  0.000000  0.006863   0.0   0.0   0.0    79   0.4    20
# 2124  140  0.000679  0.000000  0.006110   0.0   0.0   0.0    78   0.4    27
# 2125  142  0.001616  0.001616  0.008078   0.0   0.0   0.0    74   0.4    36
#
#       MLTV  Width  Min  Max  NSP
# 2121   7.2     40  137  177    2
# 2122   7.1     66  103  169    2
# 2123   6.1     67  103  170    2
# 2124   7.0     66  103  169    2
# 2125   5.0     42  117  159    1

# %%
cardio_data.describe()
# Out:
#                BPM          APC         FMPS         UCPS         DLPS  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.303857     0.003170     0.009474     0.004357     0.001885
# std       9.840844     0.003860     0.046670     0.002940     0.002962
# min     106.000000     0.000000     0.000000     0.000000     0.000000
# 25%     126.000000     0.000000     0.000000     0.001876     0.000000
# 50%     133.000000     0.001630     0.000000     0.004482     0.000000
# 75%     140.000000     0.005631     0.002512     0.006525     0.003264
# max     160.000000     0.019284     0.480634     0.014925     0.015385
#
#               SDPS         PDPS         ASTV         MSTV        ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.00000
# mean      0.000004     0.000157    46.990122     1.332785     9.84666
# std       0.000063     0.000580    17.192814     0.883241    18.39688
# min       0.000000     0.000000    12.000000     0.200000     0.00000
# 25%       0.000000     0.000000    32.000000     0.700000     0.00000
# 50%       0.000000     0.000000    49.000000     1.200000     0.00000
# 75%       0.000000     0.000000    61.000000     1.700000    11.00000
# max       0.001353     0.005348    87.000000     7.000000    91.00000
#
#               MLTV        Width          Min          Max          NSP
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      8.187629    70.445908    93.579492   164.025400     1.304327
# std       5.628247    38.955693    29.560212    17.944183     0.614377
# min       0.000000     3.000000    50.000000   122.000000     1.000000
# 25%       4.600000    37.000000    67.000000   152.000000     1.000000
# 50%       7.400000    67.500000    93.000000   162.000000     1.000000
# 75%      10.800000   100.000000   120.000000   174.000000     1.000000
# max      50.700000   180.000000   159.000000   238.000000     3.000000

# %%
cardio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BPM     2126 non-null   int64
#  1   APC     2126 non-null   float64
#  2   FMPS    2126 non-null   float64
#  3   UCPS    2126 non-null   float64
#  4   DLPS    2126 non-null   float64
#  5   SDPS    2126 non-null   float64
#  6   PDPS    2126 non-null   float64
#  7   ASTV    2126 non-null   int64
#  8   MSTV    2126 non-null   float64
#  9   ALTV    2126 non-null   int64
#  10  MLTV    2126 non-null   float64
#  11  Width   2126 non-null   int64
#  12  Min     2126 non-null   int64
#  13  Max     2126 non-null   int64
#  14  NSP     2126 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 249.3 KB

# %%
cardio_data.shape
# Out:
# (2126, 15)

# %%
cardio_data['NSP'].value_counts()
# Out:
# NSP
# 1    1655
# 2     295
# 3     176
# Name: count, dtype: int64

# %%
sns.countplot(cardio_data, x='NSP')
# Out:
# <Axes: xlabel='NSP', ylabel='count'>

# %%
X = cardio_data.drop('NSP',axis=1)
y = cardio_data['NSP'] -1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =
0.2, stratify=y, random_state=0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(9,activation='relu',input_shape=(14,)))
model.add(tf.keras.layers.Dense(3,activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics= ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 9)                   │             135 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              30 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 165 (660.00 B)
#  Trainable params: 165 (660.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
class_weights = { 0:1, 1:5.6, 2:9.4}
history = model.fit(X_train, np.asarray(y_train), \
batch_size = 32, epochs= 50, \
verbose=2, class_weight=class_weights, \
validation_split=0.2)
# Out:
# Epoch 1/50
# 43/43 - 7s - 168ms/step - accuracy: 0.4147 - loss: 3.0142 - val_accuracy: 0.4147 - val_loss: 1.2184
# Epoch 2/50
# 43/43 - 4s - 103ms/step - accuracy: 0.4566 - loss: 2.6060 - val_accuracy: 0.4676 - val_loss: 1.1385
# Epoch 3/50
# 43/43 - 0s - 7ms/step - accuracy: 0.5007 - loss: 2.3554 - val_accuracy: 0.5176 - val_loss: 1.0653
# Epoch 4/50
# 43/43 - 0s - 6ms/step - accuracy: 0.5537 - loss: 2.1526 - val_accuracy: 0.5676 - val_loss: 0.9907
# Epoch 5/50
# 43/43 - 0s - 6ms/step - accuracy: 0.6147 - loss: 1.9951 - val_accuracy: 0.6324 - val_loss: 0.9118
# Epoch 6/50
# 43/43 - 0s - 6ms/step - accuracy: 0.6574 - loss: 1.8603 - val_accuracy: 0.6647 - val_loss: 0.8449
# Epoch 7/50
# 43/43 - 0s - 3ms/step - accuracy: 0.6882 - loss: 1.7509 - val_accuracy: 0.6971 - val_loss: 0.7818
# Epoch 8/50
# 43/43 - 0s - 3ms/step - accuracy: 0.7103 - loss: 1.6571 - val_accuracy: 0.7294 - val_loss: 0.7192
# Epoch 9/50
# 43/43 - 0s - 3ms/step - accuracy: 0.7360 - loss: 1.5729 - val_accuracy: 0.7618 - val_loss: 0.6656
# Epoch 10/50
# 43/43 - 0s - 3ms/step - accuracy: 0.7574 - loss: 1.4971 - val_accuracy: 0.7794 - val_loss: 0.6227
# Epoch 11/50
# 43/43 - 0s - 3ms/step - accuracy: 0.7721 - loss: 1.4309 - val_accuracy: 0.7912 - val_loss: 0.5854
# Epoch 12/50
# 43/43 - 0s - 3ms/step - accuracy: 0.7838 - loss: 1.3761 - val_accuracy: 0.8059 - val_loss: 0.5541
# Epoch 13/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8022 - loss: 1.3258 - val_accuracy: 0.8235 - val_loss: 0.5250
# Epoch 14/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8110 - loss: 1.2832 - val_accuracy: 0.8294 - val_loss: 0.5045
# Epoch 15/50
# 43/43 - 0s - 4ms/step - accuracy: 0.8125 - loss: 1.2454 - val_accuracy: 0.8324 - val_loss: 0.4854
# Epoch 16/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8154 - loss: 1.2126 - val_accuracy: 0.8441 - val_loss: 0.4726
# Epoch 17/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8176 - loss: 1.1837 - val_accuracy: 0.8471 - val_loss: 0.4586
# Epoch 18/50
# 43/43 - 0s - 2ms/step - accuracy: 0.8243 - loss: 1.1598 - val_accuracy: 0.8529 - val_loss: 0.4464
# Epoch 19/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8265 - loss: 1.1403 - val_accuracy: 0.8500 - val_loss: 0.4374
# Epoch 20/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8257 - loss: 1.1196 - val_accuracy: 0.8500 - val_loss: 0.4312
# Epoch 21/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8265 - loss: 1.1030 - val_accuracy: 0.8559 - val_loss: 0.4201
# Epoch 22/50
# 43/43 - 0s - 2ms/step - accuracy: 0.8331 - loss: 1.0861 - val_accuracy: 0.8471 - val_loss: 0.4145
# Epoch 23/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8375 - loss: 1.0732 - val_accuracy: 0.8471 - val_loss: 0.4063
# Epoch 24/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8382 - loss: 1.0584 - val_accuracy: 0.8441 - val_loss: 0.4047
# Epoch 25/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8390 - loss: 1.0464 - val_accuracy: 0.8441 - val_loss: 0.3959
# Epoch 26/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8404 - loss: 1.0363 - val_accuracy: 0.8471 - val_loss: 0.3963
# Epoch 27/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8404 - loss: 1.0238 - val_accuracy: 0.8471 - val_loss: 0.3900
# Epoch 28/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8397 - loss: 1.0163 - val_accuracy: 0.8500 - val_loss: 0.3850
# Epoch 29/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8390 - loss: 1.0069 - val_accuracy: 0.8529 - val_loss: 0.3833
# Epoch 30/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8419 - loss: 0.9993 - val_accuracy: 0.8529 - val_loss: 0.3786
# Epoch 31/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8426 - loss: 0.9901 - val_accuracy: 0.8529 - val_loss: 0.3769
# Epoch 32/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8434 - loss: 0.9819 - val_accuracy: 0.8529 - val_loss: 0.3733
# Epoch 33/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8397 - loss: 0.9748 - val_accuracy: 0.8588 - val_loss: 0.3729
# Epoch 34/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8434 - loss: 0.9666 - val_accuracy: 0.8588 - val_loss: 0.3695
# Epoch 35/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8449 - loss: 0.9597 - val_accuracy: 0.8559 - val_loss: 0.3652
# Epoch 36/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8441 - loss: 0.9537 - val_accuracy: 0.8559 - val_loss: 0.3571
# Epoch 37/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8456 - loss: 0.9466 - val_accuracy: 0.8588 - val_loss: 0.3604
# Epoch 38/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8449 - loss: 0.9412 - val_accuracy: 0.8588 - val_loss: 0.3573
# Epoch 39/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8485 - loss: 0.9353 - val_accuracy: 0.8559 - val_loss: 0.3545
# Epoch 40/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8456 - loss: 0.9286 - val_accuracy: 0.8588 - val_loss: 0.3563
# Epoch 41/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8456 - loss: 0.9242 - val_accuracy: 0.8559 - val_loss: 0.3514
# Epoch 42/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8449 - loss: 0.9208 - val_accuracy: 0.8559 - val_loss: 0.3497
# Epoch 43/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8493 - loss: 0.9103 - val_accuracy: 0.8588 - val_loss: 0.3489
# Epoch 44/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8500 - loss: 0.9060 - val_accuracy: 0.8559 - val_loss: 0.3491
# Epoch 45/50
# 43/43 - 0s - 3ms/step - accuracy: 0.8471 - loss: 0.9004 - val_accuracy: 0.8559 - val_loss: 0.3436
# Epoch 46/50
# 43/43 - 0s - 4ms/step - accuracy: 0.8500 - loss: 0.8969 - val_accuracy: 0.8559 - val_loss: 0.3404
# Epoch 47/50
# 43/43 - 0s - 5ms/step - accuracy: 0.8471 - loss: 0.8884 - val_accuracy: 0.8529 - val_loss: 0.3436
# Epoch 48/50
# 43/43 - 0s - 4ms/step - accuracy: 0.8493 - loss: 0.8833 - val_accuracy: 0.8529 - val_loss: 0.3430
# Epoch 49/50
# 43/43 - 0s - 7ms/step - accuracy: 0.8471 - loss: 0.8781 - val_accuracy: 0.8529 - val_loss: 0.3429
# Epoch 50/50
# 43/43 - 0s - 8ms/step - accuracy: 0.8478 - loss: 0.8748 - val_accuracy: 0.8529 - val_loss: 0.3417

# %%
accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
plt.plot(accuracy, label='Training Set Accuracy')
plt.plot(validation_accuracy, label='Validation Set Accuracy')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy Across Epochs')
plt.legend()

# %%
loss = history.history['loss']
validation_loss = history.history['val_loss']
plt.plot(loss, label='Training Set Loss')
plt.plot(validation_loss, label='Validation Set Loss')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Across Epochs')
plt.legend()

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.argmax(axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
confusion_matrix = confusion_matrix(y_test,y_pred)
ax = sns.heatmap(confusion_matrix, cmap='flare',annot=True, fmt='d')
plt.xlabel("Predicted Class",fontsize=12)
plt.ylabel("True Class",fontsize=12)
plt.title("Confusion Matrix",fontsize=12)
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91       332
#            1       0.53      0.90      0.67        59
#            2       0.67      0.80      0.73        35
#
#     accuracy                           0.85       426
#    macro avg       0.73      0.85      0.77       426
# weighted avg       0.90      0.85      0.86       426
